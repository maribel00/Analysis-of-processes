# %% [markdown]
# # Analysis of the results

# %%
# Importamos todas las librerías necesarias
import pandas as pd
import numpy as np

# %%
# Leemos el dataset
df = pd.read_csv('MaribelDataset15-21.csv')
df['Grupo'] = df['Grupo'].replace('\n', '')
df = df[['Grupo']]
df.head()
# Out:
#             Grupo   Year                sTime          Session Problem  \
# 0  DBA 1516 P2 GA  Y2015  22/10/2015 17:29:21  Achernar6218896      P1
# 1  DBA 1516 P2 GA  Y2015  22/10/2015 17:29:22  Achernar6218896      P1
# 2  DBA 1516 P2 GA  Y2015  22/10/2015 17:29:39  Achernar6218896      P1
# 3  DBA 1516 P2 GA  Y2015  22/10/2015 17:34:09  Achernar7227690      P1
# 4  DBA 1516 P2 GA  Y2015  22/10/2015 17:34:10  Achernar7227690      P1
#
#    Milestone  Start Outcome  Valid    bad                          bad.1  \
# 0         20  start     NaN      1  Y20Y2  DBA 1516 P2 GAAchernar6218896
# 1         40    NaN     NaN      1  Y20Y2  DBA 1516 P2 GAAchernar6218896
# 2         60    NaN    fail      1  Y20Y2  DBA 1516 P2 GAAchernar6218896
# 3         20  start     NaN      1  Y20Y2  DBA 1516 P2 GAAchernar7227690
# 4         40    NaN     NaN      1  Y20Y2  DBA 1516 P2 GAAchernar7227690
#
#    bad.2  bad.3  bad.4      Time  sessionTime
# 0  #REF!      1      1  67541361  17,99999981
# ...

# %%
# Leemos el dataset con los coeficientes
df_dag = pd.read_csv('results.csv', sep=';')
df_dag.head()
# Out:
#          Grupo       DAG        Q1        Q2        Q3        Q4       ST
# 0  DBA1516P2GA  1.930520  1.053920  1.071510  2.055390  1.930520  15.9938
# 1  DBA1516P2GB  1.325500  1.053920  1.534530  1.341340  1.325500  10.7474
# 2  DBA1516P2GC  0.624951  0.736900  0.634708  0.624951  0.624951  24.1945
# 3  DBA1516P2GD  1.483410  0.416805  2.171620  1.335520  1.483410  14.3058
# 4  DBA1516P2GE  1.067410  0.643238  1.469130  1.432800  1.067410  23.8490

# %%
# Fusionar los DataFrames por la columna 'Grupo'
df_fusionado = pd.merge(df, df_dag, on='Grupo')

# %%
df_fusionado.head()
# Out:
# Empty DataFrame
# Columns: [Grupo, Year, sTime, Session, Problem, Milestone, Start, Outcome, Valid, bad, bad.1, bad.2, bad.3, bad.4, Time, sessionTime, DAG, Q1, Q2, Q3, Q4, ST]
# Index: []
#
# [0 rows x 22 columns]
